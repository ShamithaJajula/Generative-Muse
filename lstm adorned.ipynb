# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import utils
from textblob import TextBlob
import nltk

nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
text = open('/content/drive/My Drive/shakespeare.txt').read().splitlines()

# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text)
vocab_size = len(tokenizer.word_index) + 1

# Generate input sequences
input_sequence = []
for sent in text:
    sequence = tokenizer.texts_to_sequences([sent])[0]
    for j in range(1, len(sequence)):
        n_gram = sequence[:j+1]
        input_sequence.append(n_gram)

max_len = max([len(i) for i in input_sequence])
input_sequence = pad_sequences(input_sequence, maxlen=max_len)

# Preparing input and labels
input = input_sequence[:, :-1]
labels = input_sequence[:, -1]
labels = utils.to_categorical(labels, num_classes=vocab_size)

# Build the model
model = Sequential([
    Embedding(vocab_size, 100, input_length=max_len-1),
    LSTM(128, return_sequences=True),
    Dropout(0.2),
    LSTM(128),
    Dense(vocab_size, activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
history = model.fit(input, labels, epochs=200)

# Functions for evaluation metrics
def sentiment_score(text):
    sia = SentimentIntensityAnalyzer()
    return sia.polarity_scores(text)['compound']

def lexical_diversity(text):
    words = text.split()
    return len(set(words)) / len(words) if words else 0

def average_word_length(text):
    words = text.split()
    return np.mean([len(word) for word in words]) if words else 0

def iambic_pentameter_adherence(line):
    # Simplified check: 10 syllables with stress on every second syllable
    return True  # Placeholder

def format_adherence(sonnet):
    # Simplified check: 14 lines
    return len(sonnet.split('\n')) == 14

# Generate text using the model
def generate_text(initial_text, words_per_line=10, total_lines=14):
    new_text = initial_text
    sonnet = []
    current_line = []
    for _ in range(words_per_line * total_lines):
        tokens = tokenizer.texts_to_sequences([new_text])
        pad = pad_sequences(tokens, maxlen=max_len-1)
        preds = model.predict(pad)[0]
        next_index = np.argmax(preds)
        next_word = tokenizer.index_word.get(next_index, 'unknown')
        current_line.append(next_word)
        new_text += ' ' + next_word
        if len(current_line) >= words_per_line:
            sonnet.append(" ".join(current_line))
            current_line = []
    full_text = "\n".join(sonnet)
    return full_text, sentiment_score(full_text), lexical_diversity(full_text), average_word_length(full_text), format_adherence(full_text)

# Example usage
generated_text, sentiment, diversity, avg_word_len, adheres_format = generate_text('Adorned in shades of red')
print("Generated Text:", generated_text)
print("Sentiment Score:", sentiment)
print("Lexical Diversity:", diversity)
print("Average Word Length:", avg_word_len)
print("Format Adherence:", adheres_format)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# Mounted at /content/drive
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 10, 100)           320100
#
#  lstm (LSTM)                 (None, 10, 128)           117248
#
#  dropout (Dropout)           (None, 10, 128)           0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 3201)              412929
#
# =================================================================
# Total params: 981861 (3.75 MB)
# Trainable params: 981861 (3.75 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/200
# 485/485 [==============================] - 29s 48ms/step - loss: 6.8739 - accuracy: 0.0227
# Epoch 2/200
# 485/485 [==============================] - 25s 52ms/step - loss: 6.4973 - accuracy: 0.0265
# Epoch 3/200
# 485/485 [==============================] - 24s 50ms/step - loss: 6.3934 - accuracy: 0.0324
# Epoch 4/200
# 485/485 [==============================] - 24s 50ms/step - loss: 6.2823 - accuracy: 0.0366
# Epoch 5/200
# 485/485 [==============================] - 25s 52ms/step - loss: 6.1646 - accuracy: 0.0391
# Epoch 6/200
# 485/485 [==============================] - 23s 47ms/step - loss: 6.0503 - accuracy: 0.0436
# Epoch 7/200
# 485/485 [==============================] - 25s 52ms/step - loss: 5.9334 - accuracy: 0.0479
# Epoch 8/200
# 485/485 [==============================] - 23s 47ms/step - loss: 5.8071 - accuracy: 0.0503
# Epoch 9/200
# 485/485 [==============================] - 25s 52ms/step - loss: 5.6715 - accuracy: 0.0575
# Epoch 10/200
# 485/485 [==============================] - 24s 49ms/step - loss: 5.5254 - accuracy: 0.0621
# Epoch 11/200
# 485/485 [==============================] - 24s 49ms/step - loss: 5.3872 - accuracy: 0.0691
# Epoch 12/200
# 485/485 [==============================] - 25s 51ms/step - loss: 5.2554 - accuracy: 0.0729
# Epoch 13/200
# 485/485 [==============================] - 23s 47ms/step - loss: 5.1234 - accuracy: 0.0777
# Epoch 14/200
# 485/485 [==============================] - 25s 52ms/step - loss: 4.9954 - accuracy: 0.0860
# Epoch 15/200
# 485/485 [==============================] - 23s 47ms/step - loss: 4.8676 - accuracy: 0.0918
# Epoch 16/200
# 485/485 [==============================] - 25s 52ms/step - loss: 4.7442 - accuracy: 0.0950
# Epoch 17/200
# 485/485 [==============================] - 23s 47ms/step - loss: 4.6208 - accuracy: 0.1056
# Epoch 18/200
# 485/485 [==============================] - 28s 57ms/step - loss: 4.4964 - accuracy: 0.1147
# Epoch 19/200
# 485/485 [==============================] - 25s 52ms/step - loss: 4.3764 - accuracy: 0.1286
# Epoch 20/200
# 485/485 [==============================] - 22s 46ms/step - loss: 4.2588 - accuracy: 0.1412
# Epoch 21/200
# 485/485 [==============================] - 25s 51ms/step - loss: 4.1453 - accuracy: 0.1568
# Epoch 22/200
# 485/485 [==============================] - 23s 47ms/step - loss: 4.0419 - accuracy: 0.1748
# Epoch 23/200
# 485/485 [==============================] - 25s 51ms/step - loss: 3.9301 - accuracy: 0.1914
# Epoch 24/200
# 485/485 [==============================] - 23s 48ms/step - loss: 3.8308 - accuracy: 0.2074
# Epoch 25/200
# 485/485 [==============================] - 24s 50ms/step - loss: 3.7381 - accuracy: 0.2227
# Epoch 26/200
# 485/485 [==============================] - 24s 50ms/step - loss: 3.6456 - accuracy: 0.2372
# Epoch 27/200
# 485/485 [==============================] - 23s 47ms/step - loss: 3.5579 - accuracy: 0.2548
# Epoch 28/200
# 485/485 [==============================] - 25s 51ms/step - loss: 3.4792 - accuracy: 0.2660
# Epoch 29/200
# 485/485 [==============================] - 25s 52ms/step - loss: 3.3991 - accuracy: 0.2827
# Epoch 30/200
# 485/485 [==============================] - 25s 51ms/step - loss: 3.3253 - accuracy: 0.2935
# Epoch 31/200
# 485/485 [==============================] - 24s 49ms/step - loss: 3.2535 - accuracy: 0.3085
# Epoch 32/200
# 485/485 [==============================] - 23s 48ms/step - loss: 3.1896 - accuracy: 0.3187
# Epoch 33/200
# 485/485 [==============================] - 25s 51ms/step - loss: 3.1258 - accuracy: 0.3276
# Epoch 34/200
# 485/485 [==============================] - 22s 46ms/step - loss: 3.0605 - accuracy: 0.3385
# Epoch 35/200
# 485/485 [==============================] - 25s 51ms/step - loss: 2.9959 - accuracy: 0.3549
# Epoch 36/200
# 485/485 [==============================] - 23s 46ms/step - loss: 2.9433 - accuracy: 0.3598
# Epoch 37/200
# 485/485 [==============================] - 25s 51ms/step - loss: 2.8811 - accuracy: 0.3725
# Epoch 38/200
# 485/485 [==============================] - 23s 48ms/step - loss: 2.8273 - accuracy: 0.3814
# Epoch 39/200
# 485/485 [==============================] - 27s 55ms/step - loss: 2.7750 - accuracy: 0.3932
# Epoch 40/200
# 485/485 [==============================] - 25s 52ms/step - loss: 2.7244 - accuracy: 0.4009
# Epoch 41/200
# 485/485 [==============================] - 22s 46ms/step - loss: 2.6797 - accuracy: 0.4110
# Epoch 42/200
# 485/485 [==============================] - 25s 51ms/step - loss: 2.6240 - accuracy: 0.4239
# Epoch 43/200
# 485/485 [==============================] - 23s 47ms/step - loss: 2.5779 - accuracy: 0.4309
# Epoch 44/200
# 485/485 [==============================] - 25s 51ms/step - loss: 2.5328 - accuracy: 0.4386
# Epoch 45/200
# 485/485 [==============================] - 24s 49ms/step - loss: 2.4922 - accuracy: 0.4469
# Epoch 46/200
# 485/485 [==============================] - 23s 48ms/step - loss: 2.4462 - accuracy: 0.4596
# Epoch 47/200
# 485/485 [==============================] - 25s 51ms/step - loss: 2.4017 - accuracy: 0.4665
# Epoch 48/200
# 485/485 [==============================] - 23s 47ms/step - loss: 2.3592 - accuracy: 0.4730
# Epoch 49/200
# 485/485 [==============================] - 25s 51ms/step - loss: 2.3224 - accuracy: 0.4779
# Epoch 50/200
# 485/485 [==============================] - 25s 51ms/step - loss: 2.2786 - accuracy: 0.4923
# Epoch 51/200
# 485/485 [==============================] - 25s 51ms/step - loss: 2.2416 - accuracy: 0.5019
# Epoch 52/200
# 485/485 [==============================] - 24s 49ms/step - loss: 2.2027 - accuracy: 0.5090
# Epoch 53/200
# 485/485 [==============================] - 24s 49ms/step - loss: 2.1702 - accuracy: 0.5163
# Epoch 54/200
# 485/485 [==============================] - 24s 50ms/step - loss: 2.1291 - accuracy: 0.5261
# Epoch 55/200
# 485/485 [==============================] - 23s 47ms/step - loss: 2.0977 - accuracy: 0.5312
# Epoch 56/200
# 485/485 [==============================] - 25s 51ms/step - loss: 2.0628 - accuracy: 0.5395
# Epoch 57/200
# 485/485 [==============================] - 23s 47ms/step - loss: 2.0310 - accuracy: 0.5484
# Epoch 58/200
# 485/485 [==============================] - 25s 52ms/step - loss: 1.9958 - accuracy: 0.5511
# Epoch 59/200
# 485/485 [==============================] - 22s 46ms/step - loss: 1.9564 - accuracy: 0.5623
# Epoch 60/200
# 485/485 [==============================] - 25s 51ms/step - loss: 1.9300 - accuracy: 0.5679
# Epoch 61/200
# 485/485 [==============================] - 25s 53ms/step - loss: 1.8985 - accuracy: 0.5759
# Epoch 62/200
# 485/485 [==============================] - 24s 50ms/step - loss: 1.8655 - accuracy: 0.5863
# Epoch 63/200
# 485/485 [==============================] - 24s 49ms/step - loss: 1.8381 - accuracy: 0.5914
# Epoch 64/200
# 485/485 [==============================] - 23s 48ms/step - loss: 1.8106 - accuracy: 0.5987
# Epoch 65/200
# 485/485 [==============================] - 25s 51ms/step - loss: 1.7818 - accuracy: 0.6020
# Epoch 66/200
# 485/485 [==============================] - 22s 46ms/step - loss: 1.7500 - accuracy: 0.6076
# Epoch 67/200
# 485/485 [==============================] - 25s 51ms/step - loss: 1.7311 - accuracy: 0.6106
# Epoch 68/200
# 485/485 [==============================] - 22s 46ms/step - loss: 1.7000 - accuracy: 0.6164
# Epoch 69/200
# 485/485 [==============================] - 25s 51ms/step - loss: 1.6742 - accuracy: 0.6272
# Epoch 70/200
# 485/485 [==============================] - 22s 46ms/step - loss: 1.6409 - accuracy: 0.6338
# Epoch 71/200
# 485/485 [==============================] - 27s 56ms/step - loss: 1.6247 - accuracy: 0.6367
# Epoch 72/200
# 485/485 [==============================] - 25s 52ms/step - loss: 1.6068 - accuracy: 0.6376
# Epoch 73/200
# 485/485 [==============================] - 22s 46ms/step - loss: 1.5736 - accuracy: 0.6468
# Epoch 74/200
# 485/485 [==============================] - 24s 50ms/step - loss: 1.5528 - accuracy: 0.6501
# Epoch 75/200
# 485/485 [==============================] - 22s 46ms/step - loss: 1.5311 - accuracy: 0.6556
# Epoch 76/200
# 485/485 [==============================] - 25s 51ms/step - loss: 1.5049 - accuracy: 0.6637
# Epoch 77/200
# 485/485 [==============================] - 22s 46ms/step - loss: 1.4903 - accuracy: 0.6682
# Epoch 78/200
# 485/485 [==============================] - 25s 51ms/step - loss: 1.4578 - accuracy: 0.6746
# Epoch 79/200
# 485/485 [==============================] - 22s 46ms/step - loss: 1.4457 - accuracy: 0.6756
# Epoch 80/200
# 485/485 [==============================] - 24s 50ms/step - loss: 1.4250 - accuracy: 0.6825
# Epoch 81/200
# 485/485 [==============================] - 23s 47ms/step - loss: 1.4079 - accuracy: 0.6841
# Epoch 82/200
# 485/485 [==============================] - 26s 55ms/step - loss: 1.3874 - accuracy: 0.6887
# Epoch 83/200
# 485/485 [==============================] - 23s 47ms/step - loss: 1.3751 - accuracy: 0.6927
# Epoch 84/200
# 485/485 [==============================] - 24s 49ms/step - loss: 1.3479 - accuracy: 0.6971
# Epoch 85/200
# 485/485 [==============================] - 24s 50ms/step - loss: 1.3347 - accuracy: 0.7012
# Epoch 86/200
# 485/485 [==============================] - 23s 48ms/step - loss: 1.3149 - accuracy: 0.7021
# Epoch 87/200
# 485/485 [==============================] - 24s 50ms/step - loss: 1.3007 - accuracy: 0.7090
# Epoch 88/200
# 485/485 [==============================] - 22s 46ms/step - loss: 1.2808 - accuracy: 0.7114
# Epoch 89/200
# 485/485 [==============================] - 25s 51ms/step - loss: 1.2624 - accuracy: 0.7147
# Epoch 90/200
# 485/485 [==============================] - 22s 46ms/step - loss: 1.2444 - accuracy: 0.7184
# Epoch 91/200
# 485/485 [==============================] - 25s 51ms/step - loss: 1.2328 - accuracy: 0.7210
# Epoch 92/200
# 485/485 [==============================] - 22s 45ms/step - loss: 1.2190 - accuracy: 0.7235
# Epoch 93/200
# 485/485 [==============================] - 27s 56ms/step - loss: 1.2037 - accuracy: 0.7291
# Epoch 94/200
# 485/485 [==============================] - 23s 48ms/step - loss: 1.1907 - accuracy: 0.7308
# Epoch 95/200
# 485/485 [==============================] - 24s 49ms/step - loss: 1.1725 - accuracy: 0.7357
# Epoch 96/200
# 485/485 [==============================] - 24s 49ms/step - loss: 1.1614 - accuracy: 0.7343
# Epoch 97/200
# 485/485 [==============================] - 23s 48ms/step - loss: 1.1431 - accuracy: 0.7429
# Epoch 98/200
# 485/485 [==============================] - 24s 50ms/step - loss: 1.1380 - accuracy: 0.7395
# Epoch 99/200
# 485/485 [==============================] - 23s 47ms/step - loss: 1.1226 - accuracy: 0.7442
# Epoch 100/200
# 485/485 [==============================] - 25s 51ms/step - loss: 1.1146 - accuracy: 0.7491
# Epoch 101/200
# 485/485 [==============================] - 22s 46ms/step - loss: 1.1055 - accuracy: 0.7469
# Epoch 102/200
# 485/485 [==============================] - 25s 51ms/step - loss: 1.0888 - accuracy: 0.7533
# Epoch 103/200
# 485/485 [==============================] - 22s 46ms/step - loss: 1.0712 - accuracy: 0.7546
# Epoch 104/200
# 485/485 [==============================] - 27s 56ms/step - loss: 1.0621 - accuracy: 0.7562
# Epoch 105/200
# 485/485 [==============================] - 23s 47ms/step - loss: 1.0487 - accuracy: 0.7598
# Epoch 106/200
# 485/485 [==============================] - 24s 50ms/step - loss: 1.0383 - accuracy: 0.7631
# Epoch 107/200
# 485/485 [==============================] - 23s 48ms/step - loss: 1.0303 - accuracy: 0.7645
# Epoch 108/200
# 485/485 [==============================] - 24s 49ms/step - loss: 1.0212 - accuracy: 0.7635
# Epoch 109/200
# 485/485 [==============================] - 24s 49ms/step - loss: 1.0046 - accuracy: 0.7674
# Epoch 110/200
# 485/485 [==============================] - 23s 47ms/step - loss: 0.9911 - accuracy: 0.7736
# Epoch 111/200
# 485/485 [==============================] - 25s 52ms/step - loss: 0.9883 - accuracy: 0.7712
# Epoch 112/200
# 485/485 [==============================] - 22s 46ms/step - loss: 0.9826 - accuracy: 0.7718
# Epoch 113/200
# 485/485 [==============================] - 25s 51ms/step - loss: 0.9731 - accuracy: 0.7754
# Epoch 114/200
# 485/485 [==============================] - 23s 47ms/step - loss: 0.9634 - accuracy: 0.7760
# Epoch 115/200
# 485/485 [==============================] - 26s 55ms/step - loss: 0.9522 - accuracy: 0.7796
# Epoch 116/200
# 485/485 [==============================] - 22s 46ms/step - loss: 0.9400 - accuracy: 0.7847
# Epoch 117/200
# 485/485 [==============================] - 25s 51ms/step - loss: 0.9386 - accuracy: 0.7846
# Epoch 118/200
# 485/485 [==============================] - 23s 47ms/step - loss: 0.9233 - accuracy: 0.7833
# Epoch 119/200
# 485/485 [==============================] - 24s 50ms/step - loss: 0.9273 - accuracy: 0.7808
# Epoch 120/200
# 485/485 [==============================] - 24s 49ms/step - loss: 0.9124 - accuracy: 0.7850
# Epoch 121/200
# 485/485 [==============================] - 23s 48ms/step - loss: 0.9125 - accuracy: 0.7863
# Epoch 122/200
# 485/485 [==============================] - 25s 51ms/step - loss: 0.8906 - accuracy: 0.7919
# Epoch 123/200
# 485/485 [==============================] - 23s 46ms/step - loss: 0.8901 - accuracy: 0.7919
# Epoch 124/200
# 485/485 [==============================] - 25s 51ms/step - loss: 0.8872 - accuracy: 0.7898
# Epoch 125/200
# 485/485 [==============================] - 25s 51ms/step - loss: 0.8830 - accuracy: 0.7948
# Epoch 126/200
# 485/485 [==============================] - 24s 50ms/step - loss: 0.8782 - accuracy: 0.7930
# Epoch 127/200
# 485/485 [==============================] - 22s 45ms/step - loss: 0.8628 - accuracy: 0.7982
# Epoch 128/200
# 485/485 [==============================] - 25s 51ms/step - loss: 0.8614 - accuracy: 0.7964
# Epoch 129/200
# 485/485 [==============================] - 26s 53ms/step - loss: 0.8547 - accuracy: 0.7989
# Epoch 130/200
# 485/485 [==============================] - 23s 47ms/step - loss: 0.8496 - accuracy: 0.7978
# Epoch 131/200
# 485/485 [==============================] - 24s 50ms/step - loss: 0.8401 - accuracy: 0.8022
# Epoch 132/200
# 485/485 [==============================] - 22s 46ms/step - loss: 0.8377 - accuracy: 0.7980
# Epoch 133/200
# 485/485 [==============================] - 24s 50ms/step - loss: 0.8260 - accuracy: 0.8035
# Epoch 134/200
# 485/485 [==============================] - 22s 45ms/step - loss: 0.8216 - accuracy: 0.8043
# Epoch 135/200
# 485/485 [==============================] - 25s 52ms/step - loss: 0.8130 - accuracy: 0.8059
# Epoch 136/200
# 485/485 [==============================] - 27s 56ms/step - loss: 0.8141 - accuracy: 0.8062
# Epoch 137/200
# 485/485 [==============================] - 23s 48ms/step - loss: 0.8065 - accuracy: 0.8056
# Epoch 138/200
# 485/485 [==============================] - 26s 53ms/step - loss: 0.7989 - accuracy: 0.8105
# Epoch 139/200
# 485/485 [==============================] - 23s 48ms/step - loss: 0.7928 - accuracy: 0.8090
# Epoch 140/200
# 485/485 [==============================] - 25s 52ms/step - loss: 0.7938 - accuracy: 0.8074
# Epoch 141/200
# 485/485 [==============================] - 25s 51ms/step - loss: 0.7940 - accuracy: 0.8090
# Epoch 142/200
# 485/485 [==============================] - 23s 48ms/step - loss: 0.7849 - accuracy: 0.8104
# Epoch 143/200
# 485/485 [==============================] - 25s 52ms/step - loss: 0.7780 - accuracy: 0.8128
# Epoch 144/200
# 485/485 [==============================] - 23s 47ms/step - loss: 0.7687 - accuracy: 0.8154
# Epoch 145/200
# 485/485 [==============================] - 25s 52ms/step - loss: 0.7736 - accuracy: 0.8154
# Epoch 146/200
# 485/485 [==============================] - 28s 57ms/step - loss: 0.7728 - accuracy: 0.8135
# Epoch 147/200
# 485/485 [==============================] - 23s 47ms/step - loss: 0.7635 - accuracy: 0.8139
# Epoch 148/200
# 485/485 [==============================] - 25s 51ms/step - loss: 0.7553 - accuracy: 0.8139
# Epoch 149/200
# 485/485 [==============================] - 23s 48ms/step - loss: 0.7504 - accuracy: 0.8170
# Epoch 150/200
# 485/485 [==============================] - 25s 52ms/step - loss: 0.7449 - accuracy: 0.8184
# Epoch 151/200
# 485/485 [==============================] - 26s 54ms/step - loss: 0.7485 - accuracy: 0.8161
# Epoch 152/200
# 485/485 [==============================] - 23s 47ms/step - loss: 0.7452 - accuracy: 0.8199
# Epoch 153/200
# 485/485 [==============================] - 26s 53ms/step - loss: 0.7441 - accuracy: 0.8169
# Epoch 154/200
# 485/485 [==============================] - 27s 56ms/step - loss: 0.7348 - accuracy: 0.8168
# Epoch 155/200
# 485/485 [==============================] - 23s 48ms/step - loss: 0.7317 - accuracy: 0.8196
# Epoch 156/200
# 485/485 [==============================] - 25s 52ms/step - loss: 0.7339 - accuracy: 0.8187
# Epoch 157/200
# 485/485 [==============================] - 25s 52ms/step - loss: 0.7213 - accuracy: 0.8238
# Epoch 158/200
# 485/485 [==============================] - 25s 52ms/step - loss: 0.7229 - accuracy: 0.8205
# Epoch 159/200
# 485/485 [==============================] - 25s 51ms/step - loss: 0.7181 - accuracy: 0.8226
# Epoch 160/200
# 485/485 [==============================] - 23s 48ms/step - loss: 0.7151 - accuracy: 0.8230
# Epoch 161/200
# 485/485 [==============================] - 25s 52ms/step - loss: 0.7065 - accuracy: 0.8250
# Epoch 162/200
# 485/485 [==============================] - 23s 47ms/step - loss: 0.7121 - accuracy: 0.8239
# Epoch 163/200
# 485/485 [==============================] - 25s 52ms/step - loss: 0.7072 - accuracy: 0.8238
# Epoch 164/200
# 485/485 [==============================] - 24s 50ms/step - loss: 0.7117 - accuracy: 0.8223
# Epoch 165/200
# 485/485 [==============================] - 24s 49ms/step - loss: 0.7042 - accuracy: 0.8235
# Epoch 166/200
# 485/485 [==============================] - 26s 53ms/step - loss: 0.7003 - accuracy: 0.8239
# Epoch 167/200
# 485/485 [==============================] - 25s 53ms/step - loss: 0.6907 - accuracy: 0.8284
# Epoch 168/200
# 485/485 [==============================] - 26s 53ms/step - loss: 0.6889 - accuracy: 0.8274
# Epoch 169/200
# 485/485 [==============================] - 24s 50ms/step - loss: 0.6874 - accuracy: 0.8300
# Epoch 170/200
# 485/485 [==============================] - 24s 50ms/step - loss: 0.6808 - accuracy: 0.8290
# Epoch 171/200
# 485/485 [==============================] - 25s 52ms/step - loss: 0.6906 - accuracy: 0.8264
# Epoch 172/200
# 485/485 [==============================] - 23s 48ms/step - loss: 0.6808 - accuracy: 0.8269
# Epoch 173/200
# 485/485 [==============================] - 25s 51ms/step - loss: 0.6831 - accuracy: 0.8257
# Epoch 174/200
# 485/485 [==============================] - 24s 50ms/step - loss: 0.6837 - accuracy: 0.8257
# Epoch 175/200
# 485/485 [==============================] - 25s 51ms/step - loss: 0.6782 - accuracy: 0.8306
# Epoch 176/200
# 485/485 [==============================] - 26s 53ms/step - loss: 0.6695 - accuracy: 0.8310
# Epoch 177/200
# 485/485 [==============================] - 26s 53ms/step - loss: 0.6661 - accuracy: 0.8308
# Epoch 178/200
# 485/485 [==============================] - 26s 53ms/step - loss: 0.6663 - accuracy: 0.8307
# Epoch 179/200
# 485/485 [==============================] - 24s 50ms/step - loss: 0.6706 - accuracy: 0.8289
# Epoch 180/200
# 485/485 [==============================] - 24s 50ms/step - loss: 0.6711 - accuracy: 0.8294
# Epoch 181/200
# 485/485 [==============================] - 26s 53ms/step - loss: 0.6645 - accuracy: 0.8308
# Epoch 182/200
# 485/485 [==============================] - 24s 49ms/step - loss: 0.6614 - accuracy: 0.8311
# Epoch 183/200
# 485/485 [==============================] - 26s 53ms/step - loss: 0.6540 - accuracy: 0.8327
# Epoch 184/200
# 485/485 [==============================] - 26s 54ms/step - loss: 0.6571 - accuracy: 0.8302
# Epoch 185/200
# 485/485 [==============================] - 24s 49ms/step - loss: 0.6527 - accuracy: 0.8330
# Epoch 186/200
# 485/485 [==============================] - 26s 53ms/step - loss: 0.6521 - accuracy: 0.8344
# Epoch 187/200
# 485/485 [==============================] - 28s 59ms/step - loss: 0.6457 - accuracy: 0.8355
# Epoch 188/200
# 485/485 [==============================] - 24s 50ms/step - loss: 0.6450 - accuracy: 0.8336
# Epoch 189/200
# 485/485 [==============================] - 26s 53ms/step - loss: 0.6513 - accuracy: 0.8324
# Epoch 190/200
# 485/485 [==============================] - 26s 54ms/step - loss: 0.6488 - accuracy: 0.8312
# Epoch 191/200
# 485/485 [==============================] - 24s 49ms/step - loss: 0.6483 - accuracy: 0.8310
# Epoch 192/200
# 485/485 [==============================] - 26s 53ms/step - loss: 0.6375 - accuracy: 0.8347
# Epoch 193/200
# 485/485 [==============================] - 25s 52ms/step - loss: 0.6418 - accuracy: 0.8342
# Epoch 194/200
# 485/485 [==============================] - 24s 50ms/step - loss: 0.6338 - accuracy: 0.8345
# Epoch 195/200
# 485/485 [==============================] - 26s 54ms/step - loss: 0.6395 - accuracy: 0.8328
# Epoch 196/200
# 485/485 [==============================] - 24s 49ms/step - loss: 0.6378 - accuracy: 0.8321
# Epoch 197/200
# 485/485 [==============================] - 28s 58ms/step - loss: 0.6437 - accuracy: 0.8315
# Epoch 198/200
# 485/485 [==============================] - 26s 54ms/step - loss: 0.6316 - accuracy: 0.8342
# Epoch 199/200
# 485/485 [==============================] - 23s 48ms/step - loss: 0.6297 - accuracy: 0.8364
# Epoch 200/200
# 485/485 [==============================] - 26s 53ms/step - loss: 0.6281 - accuracy: 0.8337
# 1/1 [==============================] - 1s 929ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Generated Text: night that thou mayst come and dwell in rolling twain
# gone kind are tongue ' fired shall sing new best
# is fill of lease in me will stay the leisure
# taken shown deeds new face can truth would sing open
# treasure bad of memory sight must bear his poet's cold
# delighted sweet poet bark end than which while store shall
# land loss life alone toiled dead twain free did know
# did sing alone lost of my lays back forth me
# bow in lease ' dead live free know of truth
# in rolling in thee bow green mine so cold note
# sought view would see gone cruel in you live dead
# fired tell sweet stronger ranged living chest days do pay
# knowing me i'll again and mind alone dote write me
# of in all muse cruel prove thee one respect hours
# Sentiment Score: -0.7717
# Lexical Diversity: 0.7214285714285714
# Average Word Length: 4.0928571428571425
# Format Adherence: True
